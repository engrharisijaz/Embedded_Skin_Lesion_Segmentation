# %%
# !pip install segmentation-models
# !pip install tensorflow==2.8
# !pip install keras==2.8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: segmentation-models in c:\users\haris\appdata\roaming\python\python39\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.6.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\programdata\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.21.5)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.0.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.7.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.7.2)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.7.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (2.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (4.1.1)
# Requirement already satisfied: gast>=0.2.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.5.3)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.3.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (14.0.6)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.21.5)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (3.19.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.12.1)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (61.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.42.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (3.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.1.1)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (22.12.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.29.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras==2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (2.8.0)

# %%
import sys

sys.path.append('c:/users/haris/appdata/roaming/python/python39/site-packages')

# %%
# %matplotlib inline

# %%
import glob
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import tensorflow as tf
import segmentation_models as sm
BACKBONE = 'mobilenetv2'
preprocess_input = sm.get_preprocessing(BACKBONE)
# Out:
# Segmentation Models: using `keras` framework.

# %%
sm.set_framework('tf.keras')

sm.framework()
# Out:
# 'tf.keras'

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision


H = 224
W = 224

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(dataset_path, split=0.1):
    images = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training", "*.jpg")))
    masks = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training_Groun_Truth", "*.png")))

    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x                                ## (256, 256, 3)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)                    ## (256, 256)
    x = np.expand_dims(x, axis=-1)              ## (256, 256, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving data """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 32
    lr = 1e-4 ## (0.0001)
    num_epoch = 200
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset : 80/10/10 """
    dataset_path = "C:/Users/Haris/ICAI_Paper/Dataset"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch_size)

    train_steps = len(train_x)//batch_size
    valid_steps = len(valid_x)//batch_size

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1

    """ Model """
    model = sm.Unet(BACKBONE, encoder_weights='imagenet')
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)


    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=valid_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# Train: 2076 - 2076
# Valid: 259 - 259
# Test: 259 - 259
# Epoch 1/200
# 65/65 [==============================] - ETA: 0s - loss: 0.3675 - dice_coef: 0.4993 - iou: 0.3395 - recall_1: 0.6774 - precision_1: 0.7008
# Epoch 1: val_loss improved from inf to 2.02422, saving model to files\model.h5
# 65/65 [==============================] - 344s 5s/step - loss: 0.3675 - dice_coef: 0.4993 - iou: 0.3395 - recall_1: 0.6774 - precision_1: 0.7008 - val_loss: 2.0242 - val_dice_coef: 0.5046 - val_iou: 0.3409 - val_recall_1: 0.9924 - val_precision_1: 0.3500 - lr: 1.0000e-04
# Epoch 2/200
# 65/65 [==============================] - ETA: 0s - loss: 0.1831 - dice_coef: 0.7086 - iou: 0.5504 - recall_1: 0.8871 - precision_1: 0.9012
# Epoch 2: val_loss improved from 2.02422 to 0.32290, saving model to files\model.h5
# 65/65 [==============================] - 312s 5s/step - loss: 0.1831 - dice_coef: 0.7086 - iou: 0.5504 - recall_1: 0.8871 - precision_1: 0.9012 - val_loss: 0.3229 - val_dice_coef: 0.6665 - val_iou: 0.5011 - val_recall_1: 0.7632 - val_precision_1: 0.8294 - lr: 1.0000e-04
# Epoch 3/200
# 65/65 [==============================] - ETA: 0s - loss: 0.1216 - dice_coef: 0.7975 - iou: 0.6642 - recall_1: 0.9168 - precision_1: 0.9361
# Epoch 3: val_loss improved from 0.32290 to 0.26540, saving model to files\model.h5
# 65/65 [==============================] - 310s 5s/step - loss: 0.1216 - dice_coef: 0.7975 - iou: 0.6642 - recall_1: 0.9168 - precision_1: 0.9361 - val_loss: 0.2654 - val_dice_coef: 0.6911 - val_iou: 0.5297 - val_recall_1: 0.7268 - val_precision_1: 0.8780 - lr: 1.0000e-04
# Epoch 4/200
# 65/65 [==============================] - ETA: 0s - loss: 0.1012 - dice_coef: 0.8312 - iou: 0.7118 - recall_1: 0.9252 - precision_1: 0.9412
# Epoch 4: val_loss did not improve from 0.26540
# 65/65 [==============================] - 315s 5s/step - loss: 0.1012 - dice_coef: 0.8312 - iou: 0.7118 - recall_1: 0.9252 - precision_1: 0.9412 - val_loss: 0.2858 - val_dice_coef: 0.6679 - val_iou: 0.5054 - val_recall_1: 0.6156 - val_precision_1: 0.9291 - lr: 1.0000e-04
# Epoch 5/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0862 - dice_coef: 0.8555 - iou: 0.7480 - recall_1: 0.9331 - precision_1: 0.9493
# Epoch 5: val_loss did not improve from 0.26540
# 65/65 [==============================] - 323s 5s/step - loss: 0.0862 - dice_coef: 0.8555 - iou: 0.7480 - recall_1: 0.9331 - precision_1: 0.9493 - val_loss: 0.3407 - val_dice_coef: 0.5936 - val_iou: 0.4267 - val_recall_1: 0.4870 - val_precision_1: 0.9819 - lr: 1.0000e-04
# Epoch 6/200
# 65/65 [==============================] - ETA: 0s - loss: 0.
200
# 65/65 [==============================] - ETA: 0s - loss: 0.0416 - dice_coef: 0.9240 - iou: 0.8590 - recall_1: 0.9704 - precision_1: 0.9759
# Epoch 19: val_loss improved from 0.23588 to 0.22684, saving model to files\model.h5
# 65/65 [==============================] - 311s 5s/step - loss: 0.0416 - dice_coef: 0.9240 - iou: 0.8590 - recall_1: 0.9704 - precision_1: 0.9759 - val_loss: 0.2268 - val_dice_coef: 0.7637 - val_iou: 0.6231 - val_recall_1: 0.7188 - val_precision_1: 0.9691 - lr: 1.0000e-06
# Epoch 20/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0414 - dice_coef: 0.9243 - iou: 0.8595 - recall_1: 0.9707 - precision_1: 0.9759
# Epoch 20: val_loss improved from 0.22684 to 0.21896, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0414 - dice_coef: 0.9243 - iou: 0.8595 - recall_1: 0.9707 - precision_1: 0.9759 - val_loss: 0.2190 - val_dice_coef: 0.7720 - val_iou: 0.6339 - val_recall_1: 0.7318 - val_precision_1: 0.9674 - lr: 1.0000e-06
# Epoch 21/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0412 - dice_coef: 0.9246 - iou: 0.8601 - recall_1: 0.9709 - precision_1: 0.9761
# Epoch 21: val_loss improved from 0.21896 to 0.21204, saving model to files\model.h5
# 65/65 [==============================] - 314s 5s/step - loss: 0.0412 - dice_coef: 0.9246 - iou: 0.8601 - recall_1: 0.9709 - precision_1: 0.9761 - val_loss: 0.2120 - val_dice_coef: 0.7792 - val_iou: 0.6434 - val_recall_1: 0.7433 - val_precision_1: 0.9657 - lr: 1.0000e-06
# Epoch 22/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0410 - dice_coef: 0.9250 - iou: 0.8606 - recall_1: 0.9711 - precision_1: 0.9762
# Epoch 22: val_loss improved from 0.21204 to 0.20603, saving model to files\model.h5
# 65/65 [==============================] - 310s 5s/step - loss: 0.0410 - dice_coef: 0.9250 - iou: 0.8606 - recall_1: 0.9711 - precision_1: 0.9762 - val_loss: 0.2060 - val_dice_coef: 0.7853 - val_iou: 0.6516 - val_recall_1: 0.7540 - val_precision_1: 0.9639 - lr: 1.0000e-06
# Epoch 23/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0408 - dice_coef: 0.9253 - iou: 0.8612 - recall_1: 0.9713 - precision_1: 0.9763
# Epoch 23: val_loss improved from 0.20603 to 0.20085, saving model to files\model.h5
# 65/65 [==============================] - 311s 5s/step - loss: 0.0408 - dice_coef: 0.9253 - iou: 0.8612 - recall_1: 0.9713 - precision_1: 0.9763 - val_loss: 0.2009 - val_dice_coef: 0.7905 - val_iou: 0.6587 - val_recall_1: 0.7639 - val_precision_1: 0.9621 - lr: 1.0000e-06
# Epoch 24/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0406 - dice_coef: 0.9256 - iou: 0.8618 - recall_1: 0.9716 - precision_1: 0.9764
# Epoch 24: val_loss improved from 0.20085 to 0.19645, saving model to files\model.h5
# 65/65 [==============================] - 311s 5s/step - loss: 0.0406 - dice_coef: 0.9256 - iou: 0.8618 - recall_1: 0.9716 - precision_1: 0.9764 - val_loss: 0.1964 - val_dice_coef: 0.7950 - val_iou: 0.6650 - val_recall_1: 0.7723 - val_precision_1: 0.9602 - lr: 1.0000e-06
# Epoch 25/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0404 - dice_coef: 0.9260 - iou: 0.8623 - recall_1: 0.9718 - precision_1: 0.9766
# Epoch 25: val_loss improved from 0.19645 to 0.19293, saving model to files\model.h5
# 65/65 [==============================] - 312s 5s/step - loss: 0.0404 - dice_coef: 0.9260 - iou: 0.8623 - recall_1: 0.9718 - precision_1: 0.9766 - val_loss: 0.1929 - val_dice_coef: 0.7991 - val_iou: 0.6706 - val_recall_1: 0.7793 - val_precision_1: 0.9583 - lr: 1.0000e-06
# Epoch 26/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0402 - dice_coef: 0.9263 - iou: 0.8629 - recall_1: 0.9720 - precision_1: 0.9767
# Epoch 26: val_loss improved from 0.19293 to 0.18976, saving model to files\model.h5
# 65/65 [==============================] - 311s 5s/step - loss: 0.0402 - dice_coef: 0.9263 - iou: 0.8629 - recall_1: 0.9720 - precision_1: 0.9767 - val_loss: 0.1898 - val_dice_coef: 0.8026 - val_iou: 0.6755 - val_recall_1: 0.7854 - val_precision_1: 0.9565 - lr: 1.0000e-06
# Epoch 27/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0400 - dice_coef: 0.9266 - iou: 0.8635 - recall_1: 0.9722 - precision_1: 0.9769
# Epoch 27: val_loss improved from 0.18976 to 0.18699, saving model to files\model.h5
# 65/65 [==============================] - 312s 5s/step - loss: 0.0400 - dice_coef: 0.9266 - iou: 0.8635 - recall_1: 0.9722 - precision_1: 0.9769 - val_loss: 0.1870 - val_dice_coef: 0.8056 - val_iou: 0.6797 - val_recall_1: 0.7910 - val_precision_1: 0.9547 - lr: 1.0000e-06
# Epoch 28/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0398 - dice_coef: 0.9270 - iou: 0.8641 - recall_1: 0.9724 - precision_1: 0.9770
# Epoch 28: val_loss improved from 0.18699 to 0.18482, saving model to files\model.h5
# 65/65 [==============================] - 311s 5s/step - loss: 0.0398 - dice_coef: 0.9270 - iou: 0.8641 - recall_1: 0.9724 - precision_1: 0.9770 - val_loss: 0.1848 - val_dice_coef: 0.8083 - val_iou: 0.6835 - val_recall_1: 0.7959 - val_precision_1: 0.9530 - lr: 1.0000e-06
# Epoch 29/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0396 - dice_coef: 0.9273 - iou: 0.8646 - recall_1: 0.9726 - precision_1: 0.9771
# Epoch 29: val_loss improved from 0.18482 to 0.18289, saving model to files\model.h5
# 65/65 [==============================] - 309s 5s/step - loss: 0.0396 - dice_coef: 0.9273 - iou: 0.8646 - recall_1: 0.9726 - precision_1: 0.9771 - val_loss: 0.1829 - val_dice_coef: 0.8107 - val_iou: 0.6869 - val_recall_1: 0.8003 - val_precision_1: 0.9515 - lr: 1.0000e-06
# Epoch 30/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0394 - dice_coef: 0.9276 - iou: 0.8652 - recall_1: 0.9728 - precision_1: 0.9773
# Epoch 30: val_loss improved from 0.18289 to 0.18113, saving model to files\model.h5
# 65/65 [==============================] - 309s 5s/step - loss: 0.0394 - dice_coef: 0.9276 - iou: 0.8652 - recall_1: 0.9728 - precision_1: 0.9773 - val_loss: 0.1811 - val_dice_coef: 0.8127 - val_iou: 0.6899 - val_recall_1: 0.8043 - val_precision_1: 0.9501 - lr: 1.0000e-06
# Epoch 31/200
# 65/65 [==============================] - ETA: 0s - loss: 0.
saving model to files\model.h5
# 65/65 [==============================] - 309s 5s/step - loss: 0.0380 - dice_coef: 0.9300 - iou: 0.8694 - recall_1: 0.9742 - precision_1: 0.9783 - val_loss: 0.1714 - val_dice_coef: 0.8249 - val_iou: 0.7076 - val_recall_1: 0.8285 - val_precision_1: 0.9418 - lr: 1.0000e-06
# Epoch 38/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0378 - dice_coef: 0.9304 - iou: 0.8700 - recall_1: 0.9744 - precision_1: 0.9784
# Epoch 38: val_loss improved from 0.17142 to 0.17014, saving model to files\model.h5
# 65/65 [==============================] - 309s 5s/step - loss: 0.0378 - dice_coef: 0.9304 - iou: 0.8700 - recall_1: 0.9744 - precision_1: 0.9784 - val_loss: 0.1701 - val_dice_coef: 0.8262 - val_iou: 0.7095 - val_recall_1: 0.8309 - val_precision_1: 0.9411 - lr: 1.0000e-06
# Epoch 39/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0376 - dice_coef: 0.9307 - iou: 0.8706 - recall_1: 0.9746 - precision_1: 0.9786
# Epoch 39: val_loss improved from 0.17014 to 0.16905, saving model to files\model.h5
# 65/65 [==============================] - 309s 5s/step - loss: 0.0376 - dice_coef: 0.9307 - iou: 0.8706 - recall_1: 0.9746 - precision_1: 0.9786 - val_loss: 0.1690 - val_dice_coef: 0.8274 - val_iou: 0.7113 - val_recall_1: 0.8331 - val_precision_1: 0.9406 - lr: 1.0000e-06
# Epoch 40/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0374 - dice_coef: 0.9310 - iou: 0.8712 - recall_1: 0.9748 - precision_1: 0.9787
# Epoch 40: val_loss improved from 0.16905 to 0.16823, saving model to files\model.h5
# 65/65 [==============================] - 310s 5s/step - loss: 0.0374 - dice_coef: 0.9310 - iou: 0.8712 - recall_1: 0.9748 - precision_1: 0.9787 - val_loss: 0.1682 - val_dice_coef: 0.8284 - val_iou: 0.7127 - val_recall_1: 0.8350 - val_precision_1: 0.9400 - lr: 1.0000e-06
# Epoch 41/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0372 - dice_coef: 0.9314 - iou: 0.8718 - recall_1: 0.9750 - precision_1: 0.9789
# Epoch 41: val_loss improved from 0.16823 to 0.16760, saving model to files\model.h5
# 65/65 [==============================] - 310s 5s/step - loss: 0.0372 - dice_coef: 0.9314 - iou: 0.8718 - recall_1: 0.9750 - precision_1: 0.9789 - val_loss: 0.1676 - val_dice_coef: 0.8292 - val_iou: 0.7140 - val_recall_1: 0.8369 - val_precision_1: 0.9392 - lr: 1.0000e-06
# Epoch 42/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0370 - dice_coef: 0.9317 - iou: 0.8724 - recall_1: 0.9752 - precision_1: 0.9790
# Epoch 42: val_loss improved from 0.16760 to 0.16715, saving model to files\model.h5
# 65/65 [==============================] - 315s 5s/step - loss: 0.0370 - dice_coef: 0.9317 - iou: 0.8724 - recall_1: 0.9752 - precision_1: 0.9790 - val_loss: 0.1671 - val_dice_coef: 0.8299 - val_iou: 0.7151 - val_recall_1: 0.8385 - val_precision_1: 0.9384 - lr: 1.0000e-06
# Epoch 43/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0368 - dice_coef: 0.9320 - iou: 0.8729 - recall_1: 0.9754 - precision_1: 0.9791
# Epoch 43: val_loss improved from 0.16715 to 0.16673, saving model to files\model.h5
# 65/65 [==============================] - 315s 5s/step - loss: 0.0368 - dice_coef: 0.9320 - iou: 0.8729 - recall_1: 0.9754 - precision_1: 0.9791 - val_loss: 0.1667 - val_dice_coef: 0.8307 - val_iou: 0.7163 - val_recall_1: 0.8400 - val_precision_1: 0.9378 - lr: 1.0000e-06
# Epoch 44/200
# 65/65 [==============================] - ETA: 0s - loss: 0.
200
# 65/65 [==============================] - ETA: 0s - loss: 0.0343 - dice_coef: 0.9363 - iou: 0.8805 - recall_1: 0.9777 - precision_1: 0.9809
# Epoch 56: val_loss did not improve from 0.16404
# 65/65 [==============================] - 315s 5s/step - loss: 0.0343 - dice_coef: 0.9363 - iou: 0.8805 - recall_1: 0.9777 - precision_1: 0.9809 - val_loss: 0.1644 - val_dice_coef: 0.8380 - val_iou: 0.7273 - val_recall_1: 0.8520 - val_precision_1: 0.9348 - lr: 1.0000e-06
# Epoch 57/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0341 - dice_coef: 0.9367 - iou: 0.8811 - recall_1: 0.9778 - precision_1: 0.9811
# Epoch 57: val_loss did not improve from 0.16404
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-07.
# 65/65 [==============================] - 316s 5s/step - loss: 0.0341 - dice_coef: 0.9367 - iou: 0.8811 - recall_1: 0.9778 - precision_1: 0.9811 - val_loss: 0.1643 - val_dice_coef: 0.8385 - val_iou: 0.7281 - val_recall_1: 0.8527 - val_precision_1: 0.9347 - lr: 1.0000e-06
# Epoch 58/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9369 - iou: 0.8814 - recall_1: 0.9774 - precision_1: 0.9818
# Epoch 58: val_loss improved from 0.16404 to 0.16394, saving model to files\model.h5
# 65/65 [==============================] - 317s 5s/step - loss: 0.0339 - dice_coef: 0.9369 - iou: 0.8814 - recall_1: 0.9774 - precision_1: 0.9818 - val_loss: 0.1639 - val_dice_coef: 0.8391 - val_iou: 0.7290 - val_recall_1: 0.8537 - val_precision_1: 0.9345 - lr: 1.0000e-07
# Epoch 59/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9369 - iou: 0.8815 - recall_1: 0.9776 - precision_1: 0.9817
# Epoch 59: val_loss improved from 0.16394 to 0.16360, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0339 - dice_coef: 0.9369 - iou: 0.8815 - recall_1: 0.9776 - precision_1: 0.9817 - val_loss: 0.1636 - val_dice_coef: 0.8395 - val_iou: 0.7297 - val_recall_1: 0.8544 - val_precision_1: 0.9344 - lr: 1.0000e-07
# Epoch 60/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8816 - recall_1: 0.9777 - precision_1: 0.9816
# Epoch 60: val_loss improved from 0.16360 to 0.16323, saving model to files\model.h5
# 65/65 [==============================] - 317s 5s/step - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8816 - recall_1: 0.9777 - precision_1: 0.9816 - val_loss: 0.1632 - val_dice_coef: 0.8399 - val_iou: 0.7303 - val_recall_1: 0.8551 - val_precision_1: 0.9344 - lr: 1.0000e-07
# Epoch 61/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8816 - recall_1: 0.9778 - precision_1: 0.9816
# Epoch 61: val_loss improved from 0.16323 to 0.16296, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8816 - recall_1: 0.9778 - precision_1: 0.9816 - val_loss: 0.1630 - val_dice_coef: 0.8401 - val_iou: 0.7307 - val_recall_1: 0.8556 - val_precision_1: 0.9343 - lr: 1.0000e-07
# Epoch 62/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8817 - recall_1: 0.9779 - precision_1: 0.9815
# Epoch 62: val_loss improved from 0.16296 to 0.16276, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0339 - dice_coef: 0.9370 - iou: 0.8817 - recall_1: 0.9779 - precision_1: 0.9815 - val_loss: 0.1628 - val_dice_coef: 0.8404 - val_iou: 0.7310 - val_recall_1: 0.8560 - val_precision_1: 0.9342 - lr: 1.0000e-07
# Epoch 63/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8818 - recall_1: 0.9780 - precision_1: 0.9815
# Epoch 63: val_loss improved from 0.16276 to 0.16258, saving model to files\model.h5
# 65/65 [==============================] - 317s 5s/step - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8818 - recall_1: 0.9780 - precision_1: 0.9815 - val_loss: 0.1626 - val_dice_coef: 0.8405 - val_iou: 0.7313 - val_recall_1: 0.8564 - val_precision_1: 0.9341 - lr: 1.0000e-07
# Epoch 64/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8818 - recall_1: 0.9780 - precision_1: 0.9815
# Epoch 64: val_loss improved from 0.16258 to 0.16246, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8818 - recall_1: 0.9780 - precision_1: 0.9815 - val_loss: 0.1625 - val_dice_coef: 0.8407 - val_iou: 0.7315 - val_recall_1: 0.8567 - val_precision_1: 0.9340 - lr: 1.0000e-07
# Epoch 65/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8819 - recall_1: 0.9781 - precision_1: 0.9814
# Epoch 65: val_loss improved from 0.16246 to 0.16231, saving model to files\model.h5
# 65/65 [==============================] - 316s 5s/step - loss: 0.0338 - dice_coef: 0.9371 - iou: 0.8819 - recall_1: 0.9781 - precision_1: 0.9814 - val_loss: 0.1623 - val_dice_coef: 0.8409 - val_iou: 0.7318 - val_recall_1: 0.8571 - val_precision_1: 0.9339 - lr: 1.0000e-07
# Epoch 66/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9372 - iou: 0.8820 - recall_1: 0.9781 - precision_1: 0.9814
# Epoch 66: val_loss improved from 0.16231 to 0.16211, saving model to files\model.h5
# 65/65 [==============================] - 317s 5s/step - loss: 0.0338 - dice_coef: 0.9372 - iou: 0.8820 - recall_1: 0.9781 - precision_1: 0.9814 - val_loss: 0.1621 - val_dice_coef: 0.8410 - val_iou: 0.7321 - val_recall_1: 0.8575 - val_precision_1: 0.9338 - lr: 1.0000e-07
# Epoch 67/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9372 - iou: 0.8820 - recall_1: 0.9781 - precision_1: 0.9814
# Epoch 67: val_loss improved from 0.16211 to 0.16197, saving model to files\model.h5
# 65/65 [==============================] - 310s 5s/step - loss: 0.0338 - dice_coef: 0.9372 - iou: 0.8820 - recall_1: 0.9781 - precision_1: 0.9814 - val_loss: 0.1620 - val_dice_coef: 0.8412 - val_iou: 0.7324 - val_recall_1: 0.8579 - val_precision_1: 0.9337 - lr: 1.0000e-07
# Epoch 68/200
# 65/65 [==============================] - ETA: 0s - loss: 0.
200
# 65/65 [==============================] - ETA: 0s - loss: 0.0330 - dice_coef: 0.9386 - iou: 0.8845 - recall_1: 0.9789 - precision_1: 0.9819
# Epoch 105: val_loss did not improve from 0.16075
# 65/65 [==============================] - 323s 5s/step - loss: 0.0330 - dice_coef: 0.9386 - iou: 0.8845 - recall_1: 0.9789 - precision_1: 0.9819 - val_loss: 0.1610 - val_dice_coef: 0.8441 - val_iou: 0.7365 - val_recall_1: 0.8623 - val_precision_1: 0.9319 - lr: 1.0000e-07
# Epoch 106/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0330 - dice_coef: 0.9387 - iou: 0.8846 - recall_1: 0.9789 - precision_1: 0.9819
# Epoch 106: val_loss did not improve from 0.16075
# 65/65 [==============================] - 323s 5s/step - loss: 0.0330 - dice_coef: 0.9387 - iou: 0.8846 - recall_1: 0.9789 - precision_1: 0.9819 - val_loss: 0.1610 - val_dice_coef: 0.8441 - val_iou: 0.7365 - val_recall_1: 0.8623 - val_precision_1: 0.9319 - lr: 1.0000e-07
# Epoch 107/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.9387 - iou: 0.8846 - recall_1: 0.9789 - precision_1: 0.9819
# Epoch 107: val_loss did not improve from 0.16075
# 65/65 [==============================] - 323s 5s/step - loss: 0.0329 - dice_coef: 0.9387 - iou: 0.8846 - recall_1: 0.9789 - precision_1: 0.9819 - val_loss: 0.1610 - val_dice_coef: 0.8442 - val_iou: 0.7366 - val_recall_1: 0.8623 - val_precision_1: 0.9319 - lr: 1.0000e-07
# Epoch 108/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.9387 - iou: 0.8847 - recall_1: 0.9789 - precision_1: 0.9820
# Epoch 108: val_loss did not improve from 0.16075
# 65/65 [==============================] - 323s 5s/step - loss: 0.0329 - dice_coef: 0.9387 - iou: 0.8847 - recall_1: 0.9789 - precision_1: 0.9820 - val_loss: 0.1610 - val_dice_coef: 0.8442 - val_iou: 0.7366 - val_recall_1: 0.8624 - val_precision_1: 0.9319 - lr: 1.0000e-07
# Epoch 109/200
# 65/65 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.9388 - iou: 0.8848 - recall_1: 0.9790 - precision_1: 0.9820
# Epoch 109: val_loss did not improve from 0.16075
# 65/65 [==============================] - 322s 5s/step - loss: 0.0329 - dice_coef: 0.9388 - iou: 0.8848 - recall_1: 0.9790 - precision_1: 0.9820 - val_loss: 0.1611 - val_dice_coef: 0.8442 - val_iou: 0.7366 - val_recall_1: 0.8624 - val_precision_1: 0.9319 - lr: 1.0000e-07

# %%
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_2[0][0]']
#                                 3)
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['Conv1_pad[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['out_relu[0][0]']
#  ampling2D)                     1280)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          1856)                            ',
#                                                                   'block_13_expand_relu[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   4276224     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          448)                             ',
#                                                                   'block_6_expand_relu[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   516096      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          272)                             ',
#                                                                   'block_3_expand_relu[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   156672      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          160)                             ',
#                                                                   'block_1_expand_relu[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   46080       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   145         ['decoder_stage4b_relu[0][0]']
#                                 1)
#
#  sigmoid (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 8,047,441
# Trainable params: 8,011,345
# Non-trainable params: 36,096
# __________________________________________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score



H = 256
W = 256

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    return ori_x, x                                ## (1, 256, 256, 3)


def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)                    ## (256, 256)
    return ori_x, x

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)  ## (256, 256, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1) ## (256, 256, 3)

    y_pred = np.expand_dims(y_pred, axis=-1)  ## (256, 256, 1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) ## (256, 256, 3)

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_images)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving results """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
        model = tf.keras.models.load_model("files/model.h5")

    """ Load the test data """
    dataset_path = "C:/Users/Haris/ICAI_Paper"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Exctracting the image name """
        name = x.split("/")[-1]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Predicting the mask """
        y_pred = model.predict(x)[0] > 0.5
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred.astype(np.int32)

        """ Saving the predicted mask """
        save_image_path = f"results/{name}"
        save_results(ori_x, ori_y, y_pred, save_image_path)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ mean metrics values """
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns = ["Image Name", "Acc", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 259/259 [01:11<00:00,  3.63it/s]
# Accuracy: 0.95758
# F1: 0.88633
# Jaccard: 0.80877
# Recall: 0.90138
# Precision: 0.89768

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    """ Model """
    model = Model(inputs, outputs)
    return model

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision


H = 224
W = 224

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(dataset_path, split=0.1):
    images = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training", "*.jpg")))
    masks = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training_Groun_Truth", "*.png")))

    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x                                ## (256, 256, 3)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)                    ## (256, 256)
    x = np.expand_dims(x, axis=-1)              ## (256, 256, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving data """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 16
    lr = 1e-4 ## (0.0001)
    num_epoch = 200
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset : 80/10/10 """
    dataset_path = "C:/Users/Haris/ICAI_Paper/Dataset"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch_size)

    train_steps = len(train_x)//batch_size
    valid_steps = len(valid_x)//batch_size

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1

    """ Model """
    model = build_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)


    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=valid_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# Train: 2076 - 2076
# Valid: 259 - 259
# Test: 259 - 259
# Epoch 1/200
# 130/130 [==============================] - ETA: 0s - loss: 0.3143 - dice_coef: 0.5800 - iou: 0.4135 - recall_1: 0.6631 - precision_1: 0.7455
# Epoch 1: val_loss improved from inf to 0.53061, saving model to files\model.h5
# 130/130 [==============================] - 344s 3s/step - loss: 0.3143 - dice_coef: 0.5800 - iou: 0.4135 - recall_1: 0.6631 - precision_1: 0.7455 - val_loss: 0.5306 - val_dice_coef: 0.2563 - val_iou: 0.1472 - val_recall_1: 0.0428 - val_precision_1: 0.9943 - lr: 1.0000e-04
# Epoch 2/200
# 130/130 [==============================] - ETA: 0s - loss: 0.2121 - dice_coef: 0.6931 - iou: 0.5325 - recall_1: 0.7572 - precision_1: 0.8557
# Epoch 2: val_loss improved from 0.53061 to 0.51358, saving model to files\model.h5
# 130/130 [==============================] - 321s 2s/step - loss: 0.2121 - dice_coef: 0.6931 - iou: 0.5325 - recall_1: 0.7572 - precision_1: 0.8557 - val_loss: 0.5136 - val_dice_coef: 0.3804 - val_iou: 0.2385 - val_recall_1: 0.2396 - val_precision_1: 0.9209 - lr: 1.0000e-04
# Epoch 3/200
# 130/130 [==============================] - ETA: 0s - loss: 0.1831 - dice_coef: 0.7328 - iou: 0.5805 - recall_1: 0.7937 - precision_1: 0.8734
# Epoch 3: val_loss improved from 0.51358 to 0.23439, saving model to files\model.h5
# 130/130 [==============================] - 321s 2s/step - loss: 0.1831 - dice_coef: 0.7328 - iou: 0.5805 - recall_1: 0.7937 - precision_1: 0.8734 - val_loss: 0.2344 - val_dice_coef: 0.7086 - val_iou: 0.5534 - val_recall_1: 0.7246 - val_precision_1: 0.8682 - lr: 1.0000e-04
# Epoch 4/200
# 130/130 [==============================] - ETA: 0s - loss: 0.1672 - dice_coef: 0.7555 - iou: 0.6092 - recall_1: 0.8144 - precision_1: 0.8798
# Epoch 4: val_loss improved from 0.23439 to 0.18663, saving model to files\model.h5
# 130/130 [==============================] - 321s 2s/step - loss: 0.1672 - dice_coef: 0.7555 - iou: 0.6092 - recall_1: 0.8144 - precision_1: 0.8798 - val_loss: 0.1866 - val_dice_coef: 0.7583 - val_iou: 0.6131 - val_recall_1: 0.8500 - val_precision_1: 0.8391 - lr: 1.0000e-04
# Epoch 5/200
# 130/130 [==============================] - ETA: 0s - loss: 0.
200
# 130/130 [==============================] - ETA: 0s - loss: 0.0833 - dice_coef: 0.8774 - iou: 0.7823 - recall_1: 0.9072 - precision_1: 0.9355
# Epoch 18: val_loss did not improve from 0.14566
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 130/130 [==============================] - 310s 2s/step - loss: 0.0833 - dice_coef: 0.8774 - iou: 0.7823 - recall_1: 0.9072 - precision_1: 0.9355 - val_loss: 0.1637 - val_dice_coef: 0.8275 - val_iou: 0.7081 - val_recall_1: 0.8030 - val_precision_1: 0.9532 - lr: 1.0000e-04
# Epoch 19/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0727 - dice_coef: 0.8912 - iou: 0.8044 - recall_1: 0.9223 - precision_1: 0.9400
# Epoch 19: val_loss improved from 0.14566 to 0.12983, saving model to files\model.h5
# 130/130 [==============================] - 310s 2s/step - loss: 0.0727 - dice_coef: 0.8912 - iou: 0.8044 - recall_1: 0.9223 - precision_1: 0.9400 - val_loss: 0.1298 - val_dice_coef: 0.8572 - val_iou: 0.7516 - val_recall_1: 0.8641 - val_precision_1: 0.9285 - lr: 1.0000e-05
# Epoch 20/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0650 - dice_coef: 0.9003 - iou: 0.8191 - recall_1: 0.9302 - precision_1: 0.9473
# Epoch 20: val_loss improved from 0.12983 to 0.12753, saving model to files\model.h5
# 130/130 [==============================] - 311s 2s/step - loss: 0.0650 - dice_coef: 0.9003 - iou: 0.8191 - recall_1: 0.9302 - precision_1: 0.9473 - val_loss: 0.1275 - val_dice_coef: 0.8596 - val_iou: 0.7552 - val_recall_1: 0.8716 - val_precision_1: 0.9266 - lr: 1.0000e-05
# Epoch 21/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0617 - dice_coef: 0.9052 - iou: 0.8272 - recall_1: 0.9341 - precision_1: 0.9499
# Epoch 21: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0617 - dice_coef: 0.9052 - iou: 0.8272 - recall_1: 0.9341 - precision_1: 0.9499 - val_loss: 0.1284 - val_dice_coef: 0.8616 - val_iou: 0.7582 - val_recall_1: 0.8743 - val_precision_1: 0.9244 - lr: 1.0000e-05
# Epoch 22/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0594 - dice_coef: 0.9086 - iou: 0.8328 - recall_1: 0.9368 - precision_1: 0.9517
# Epoch 22: val_loss did not improve from 0.12753
# 130/130 [==============================] - 309s 2s/step - loss: 0.0594 - dice_coef: 0.9086 - iou: 0.8328 - recall_1: 0.9368 - precision_1: 0.9517 - val_loss: 0.1295 - val_dice_coef: 0.8637 - val_iou: 0.7615 - val_recall_1: 0.8759 - val_precision_1: 0.9232 - lr: 1.0000e-05
# Epoch 23/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0575 - dice_coef: 0.9114 - iou: 0.8375 - recall_1: 0.9390 - precision_1: 0.9533
# Epoch 23: val_loss did not improve from 0.12753
# 130/130 [==============================] - 309s 2s/step - loss: 0.0575 - dice_coef: 0.9114 - iou: 0.8375 - recall_1: 0.9390 - precision_1: 0.9533 - val_loss: 0.1310 - val_dice_coef: 0.8654 - val_iou: 0.7641 - val_recall_1: 0.8771 - val_precision_1: 0.9222 - lr: 1.0000e-05
# Epoch 24/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0557 - dice_coef: 0.9139 - iou: 0.8419 - recall_1: 0.9410 - precision_1: 0.9549
# Epoch 24: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0557 - dice_coef: 0.9139 - iou: 0.8419 - recall_1: 0.9410 - precision_1: 0.9549 - val_loss: 0.1327 - val_dice_coef: 0.8670 - val_iou: 0.7665 - val_recall_1: 0.8779 - val_precision_1: 0.9216 - lr: 1.0000e-05
# Epoch 25/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0540 - dice_coef: 0.9163 - iou: 0.8458 - recall_1: 0.9428 - precision_1: 0.9563
# Epoch 25: val_loss did not improve from 0.12753
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 130/130 [==============================] - 310s 2s/step - loss: 0.0540 - dice_coef: 0.9163 - iou: 0.8458 - recall_1: 0.9428 - precision_1: 0.9563 - val_loss: 0.1347 - val_dice_coef: 0.8680 - val_iou: 0.7681 - val_recall_1: 0.8774 - val_precision_1: 0.9216 - lr: 1.0000e-05
# Epoch 26/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0524 - dice_coef: 0.9177 - iou: 0.8482 - recall_1: 0.9473 - precision_1: 0.9549
# Epoch 26: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0524 - dice_coef: 0.9177 - iou: 0.8482 - recall_1: 0.9473 - precision_1: 0.9549 - val_loss: 0.1352 - val_dice_coef: 0.8713 - val_iou: 0.7734 - val_recall_1: 0.8703 - val_precision_1: 0.9313 - lr: 1.0000e-06
# Epoch 27/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0518 - dice_coef: 0.9188 - iou: 0.8500 - recall_1: 0.9452 - precision_1: 0.9582
# Epoch 27: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0518 - dice_coef: 0.9188 - iou: 0.8500 - recall_1: 0.9452 - precision_1: 0.9582 - val_loss: 0.1358 - val_dice_coef: 0.8720 - val_iou: 0.7745 - val_recall_1: 0.8713 - val_precision_1: 0.9305 - lr: 1.0000e-06
# Epoch 28/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0515 - dice_coef: 0.9194 - iou: 0.8510 - recall_1: 0.9455 - precision_1: 0.9584
# Epoch 28: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0515 - dice_coef: 0.9194 - iou: 0.8510 - recall_1: 0.9455 - precision_1: 0.9584 - val_loss: 0.1363 - val_dice_coef: 0.8724 - val_iou: 0.7750 - val_recall_1: 0.8718 - val_precision_1: 0.9301 - lr: 1.0000e-06
# Epoch 29/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0513 - dice_coef: 0.9198 - iou: 0.8518 - recall_1: 0.9458 - precision_1: 0.9586
# Epoch 29: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0513 - dice_coef: 0.9198 - iou: 0.8518 - recall_1: 0.9458 - precision_1: 0.9586 - val_loss: 0.1368 - val_dice_coef: 0.8726 - val_iou: 0.7754 - val_recall_1: 0.8719 - val_precision_1: 0.9299 - lr: 1.0000e-06
# Epoch 30/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0511 - dice_coef: 0.9202 - iou: 0.8525 - recall_1: 0.9461 - precision_1: 0.9587
# Epoch 30: val_loss did not improve from 0.12753
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-07.
# 130/130 [==============================] - 310s 2s/step - loss: 0.0511 - dice_coef: 0.9202 - iou: 0.8525 - recall_1: 0.9461 - precision_1: 0.9587 - val_loss: 0.1372 - val_dice_coef: 0.8728 - val_iou: 0.7757 - val_recall_1: 0.8719 - val_precision_1: 0.9298 - lr: 1.0000e-06
# Epoch 31/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0507 - dice_coef: 0.9205 - iou: 0.8530 - recall_1: 0.9442 - precision_1: 0.9611
# Epoch 31: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0507 - dice_coef: 0.9205 - iou: 0.8530 - recall_1: 0.9442 - precision_1: 0.9611 - val_loss: 0.1375 - val_dice_coef: 0.8727 - val_iou: 0.7755 - val_recall_1: 0.8711 - val_precision_1: 0.9305 - lr: 1.0000e-07
# Epoch 32/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0507 - dice_coef: 0.9206 - iou: 0.8531 - recall_1: 0.9451 - precision_1: 0.9604
# Epoch 32: val_loss did not improve from 0.12753
# 130/130 [==============================] - 311s 2s/step - loss: 0.0507 - dice_coef: 0.9206 - iou: 0.8531 - recall_1: 0.9451 - precision_1: 0.9604 - val_loss: 0.1375 - val_dice_coef: 0.8728 - val_iou: 0.7756 - val_recall_1: 0.8715 - val_precision_1: 0.9301 - lr: 1.0000e-07
# Epoch 33/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0506 - dice_coef: 0.9207 - iou: 0.8533 - recall_1: 0.9457 - precision_1: 0.9599
# Epoch 33: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0506 - dice_coef: 0.9207 - iou: 0.8533 - recall_1: 0.9457 - precision_1: 0.9599 - val_loss: 0.1374 - val_dice_coef: 0.8729 - val_iou: 0.7758 - val_recall_1: 0.8721 - val_precision_1: 0.9296 - lr: 1.0000e-07
# Epoch 34/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0506 - dice_coef: 0.9207 - iou: 0.8534 - recall_1: 0.9461 - precision_1: 0.9596
# Epoch 34: val_loss did not improve from 0.12753
# 130/130 [==============================] - 311s 2s/step - loss: 0.0506 - dice_coef: 0.9207 - iou: 0.8534 - recall_1: 0.9461 - precision_1: 0.9596 - val_loss: 0.1374 - val_dice_coef: 0.8729 - val_iou: 0.7759 - val_recall_1: 0.8725 - val_precision_1: 0.9292 - lr: 1.0000e-07
# Epoch 35/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0506 - dice_coef: 0.9208 - iou: 0.8535 - recall_1: 0.9463 - precision_1: 0.9594
# Epoch 35: val_loss did not improve from 0.12753
# 130/130 [==============================] - 311s 2s/step - loss: 0.0506 - dice_coef: 0.9208 - iou: 0.8535 - recall_1: 0.9463 - precision_1: 0.9594 - val_loss: 0.1374 - val_dice_coef: 0.8730 - val_iou: 0.7760 - val_recall_1: 0.8728 - val_precision_1: 0.9289 - lr: 1.0000e-07
# Epoch 36/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9208 - iou: 0.8536 - recall_1: 0.9465 - precision_1: 0.9593
# Epoch 36: val_loss did not improve from 0.12753
# 130/130 [==============================] - 311s 2s/step - loss: 0.0505 - dice_coef: 0.9208 - iou: 0.8536 - recall_1: 0.9465 - precision_1: 0.9593 - val_loss: 0.1374 - val_dice_coef: 0.8730 - val_iou: 0.7760 - val_recall_1: 0.8731 - val_precision_1: 0.9287 - lr: 1.0000e-07
# Epoch 37/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9209 - iou: 0.8536 - recall_1: 0.9466 - precision_1: 0.9592
# Epoch 37: val_loss did not improve from 0.12753
# 130/130 [==============================] - 311s 2s/step - loss: 0.0505 - dice_coef: 0.9209 - iou: 0.8536 - recall_1: 0.9466 - precision_1: 0.9592 - val_loss: 0.1375 - val_dice_coef: 0.8731 - val_iou: 0.7761 - val_recall_1: 0.8732 - val_precision_1: 0.9285 - lr: 1.0000e-07
# Epoch 38/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9209 - iou: 0.8537 - recall_1: 0.9467 - precision_1: 0.9592
# Epoch 38: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0505 - dice_coef: 0.9209 - iou: 0.8537 - recall_1: 0.9467 - precision_1: 0.9592 - val_loss: 0.1375 - val_dice_coef: 0.8731 - val_iou: 0.7761 - val_recall_1: 0.8733 - val_precision_1: 0.9285 - lr: 1.0000e-07
# Epoch 39/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9210 - iou: 0.8538 - recall_1: 0.9468 - precision_1: 0.9592
# Epoch 39: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0505 - dice_coef: 0.9210 - iou: 0.8538 - recall_1: 0.9468 - precision_1: 0.9592 - val_loss: 0.1376 - val_dice_coef: 0.8731 - val_iou: 0.7762 - val_recall_1: 0.8734 - val_precision_1: 0.9284 - lr: 1.0000e-07
# Epoch 40/200
# 130/130 [==============================] - ETA: 0s - loss: 0.0505 - dice_coef: 0.9210 - iou: 0.8539 - recall_1: 0.9468 - precision_1: 0.9592
# Epoch 40: val_loss did not improve from 0.12753
# 130/130 [==============================] - 310s 2s/step - loss: 0.0505 - dice_coef: 0.9210 - iou: 0.8539 - recall_1: 0.9468 - precision_1: 0.9592 - val_loss: 0.1376 - val_dice_coef: 0.8732 - val_iou: 0.7762 - val_recall_1: 0.8734 - val_precision_1: 0.9284 - lr: 1.0000e-07

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score



H = 224
W = 224

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    return ori_x, x                                ## (1, 256, 256, 3)


def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)                    ## (256, 256)
    return ori_x, x

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)  ## (256, 256, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1) ## (256, 256, 3)

    y_pred = np.expand_dims(y_pred, axis=-1)  ## (256, 256, 1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) ## (256, 256, 3)

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_images)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving results """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
        model = tf.keras.models.load_model("files/model.h5")

    """ Load the test data """
    dataset_path = "/content/drive/MyDrive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Exctracting the image name """
        name = x.split("/")[-1]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Predicting the mask """
        y_pred = model.predict(x)[0] > 0.5
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred.astype(np.int32)

        """ Saving the predicted mask """
        save_image_path = f"results/{name}"
        save_results(ori_x, ori_y, y_pred, save_image_path)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ mean metrics values """
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns = ["Image Name", "Acc", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
#  69%|███████████████████████████████████████████████████████▌                        | 180/259 [00:53<00:11,  6.94it/s]C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 252/259 [01:13<00:01,  4.46it/s]C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|████████████████████████████████████████████████████████████████████████████████| 259/259 [01:14<00:00,  3.47it/s]
# Accuracy: 0.95681
# F1: 0.88410
# Jaccard: 0.81170
# Recall: 0.91029
# Precision: 0.88815

# %%
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 224, 224, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 224, 224, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 224, 224, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 64  0          ['activation_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 112, 112, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 112, 112, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 112, 112, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 128)  0          ['activation_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 256)  0          ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 1024  9438208     ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 28, 28, 512)  2097664    ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 56, 56, 256)  524544     ['activation_29[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 112, 112, 12  131200     ['activation_31[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'activation_21[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 112, 112, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  activation_32 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 112, 112, 12  147584      ['activation_32[0][0]']
#                                 8)
#
#  batch_normalization_33 (BatchN  (None, 112, 112, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  activation_33 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 224, 224, 64  32832      ['activation_33[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 224, 224, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 224, 224, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 224, 224, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 224, 224, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 224, 224, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 224, 224, 1)  65          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np


from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import pandas as pd
from glob import glob
from tqdm import tqdm
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score

import sys

sys.path.append('c:/users/haris/appdata/roaming/python/python39/site-packages')
import cv2
H = 224
W = 224
IMAGE_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 2


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)


def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y


def load_data(dataset_path, split=0.1):
    images = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training", "*.jpg")))
    masks = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset/ISIC2018_Training_Groun_Truth", "*.png")))

    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)


def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ##(H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x  ##(256, 256, 3)


def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ##(H, W)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)  ##(256, 256)
    x = np.expand_dims(x, axis=-1)  ##(256, 256, 1)
    return x


def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)


def convolution_block(
        block_input,
        num_filters=256,
        kernel_size=3,
        dilation_rate=1,
        padding="same",
        use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output


def DeeplabV3Plus(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    resnet50 = keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_tensor=model_input
    )
    x = resnet50.get_layer("conv4_block6_2_relu").output
    x = DilatedSpatialPyramidPooling(x)

    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return keras.Model(inputs=model_input, outputs=model_output)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving data """
    create_dir("files")

    """ Hyperparameters """

    batch_size = 32
    lr = 1e-4  ##(0.0001)
    num_epoch = 100
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset : 60/20/20 """
    dataset_path = "C:/Users/Haris/ICAI_Paper/Dataset/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch_size)
    val_dataset = tf_dataset(valid_x, valid_y, batch_size)

    train_steps = len(train_x) // batch_size
    valid_steps = len(valid_x) // batch_size

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1

    print("Train Dataset:", train_dataset)
    print("Val Dataset:", val_dataset)


    model = DeeplabV3Plus(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
    model.summary()

    metrics = [dice_coef, iou, Recall(), Precision(), "accuracy"]
    model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
    ]

    history = model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=val_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )



    plt.plot(history.history["loss"])
    plt.title("Training Loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.show()

    plt.plot(history.history["accuracy"])
    plt.title("Training Accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.show()

    plt.plot(history.history["val_loss"])
    plt.title("Validation Loss")
    plt.ylabel("val_loss")
    plt.xlabel("epoch")
    plt.show()

    plt.plot(history.history["val_accuracy"])
    plt.title("Validation Accuracy")
    plt.ylabel("val_accuracy")
    plt.xlabel("epoch")
    plt.show()


def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    return ori_x, x                                ## (1, 256, 256, 3)


def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)                    ## (256, 256)
    return ori_x, x

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)  ## (256, 256, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1) ## (256, 256, 3)

    y_pred = np.expand_dims(y_pred, axis=-1)  ## (256, 256, 1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) ## (256, 256, 3)

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_images)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving results """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
        model = tf.keras.models.load_model("files/model.h5")

    """ Load the test data """
    dataset_path = "/content/drive/MyDrive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Exctracting the image name """
        name = x.split("/")[-1]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Predicting the mask """
        y_pred = model.predict(x)[0] > 0.5
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred.astype(np.int32)

        """ Saving the predicted mask """
        save_image_path = f"results/{name}"
        save_results(ori_x, ori_y, y_pred, save_image_path)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ mean metrics values """
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns = ["Image Name", "Acc", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
# Train: 2076 - 2076
# Valid: 259 - 259
# Test: 259 - 259
# Train Dataset: <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 224, 224, 1), dtype=tf.float32, name=None))>
# Val Dataset: <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 224, 224, 1), dtype=tf.float32, name=None))>
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 256)   0           ['conv4_block6_2_relu[0][0]']
#  oling2D)
#
#  conv2d_10 (Conv2D)             (None, 1, 1, 256)    65792       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 1, 1, 256)   1024        ['conv2d_10[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 256)  65536       ['conv4_block6_2_relu[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  tf.nn.relu_9 (TFOpLambda)      (None, 1, 1, 256)    0           ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 14, 14, 256)  0          ['tf.nn.relu_9[0][0]']
#
#  tf.nn.relu_10 (TFOpLambda)     (None, 14, 14, 256)  0           ['batch_normalization_10[0][0]']
#
#  tf.nn.relu_11 (TFOpLambda)     (None, 14, 14, 256)  0           ['batch_normalization_11[0][0]']
#
#  tf.nn.relu_12 (TFOpLambda)     (None, 14, 14, 256)  0           ['batch_normalization_12[0][0]']
#
#  tf.nn.relu_13 (TFOpLambda)     (None, 14, 14, 256)  0           ['batch_normalization_13[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 1280  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'tf.nn.relu_10[0][0]',
#                                                                   'tf.nn.relu_11[0][0]',
#                                                                   'tf.nn.relu_12[0][0]',
#                                                                   'tf.nn.relu_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 256)  327680      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 48)   3072        ['conv2_block3_2_relu[0][0]']
#
#  tf.nn.relu_14 (TFOpLambda)     (None, 14, 14, 256)  0           ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 48)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 56, 56, 256)  0          ['tf.nn.relu_14[0][0]']
#
#  tf.nn.relu_15 (TFOpLambda)     (None, 56, 56, 48)   0           ['batch_normalization_15[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 304)  0           ['up_sampling2d_4[0][0]',
#                                                                   'tf.nn.relu_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 56, 56, 256)  700416      ['concatenate_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  tf.nn.relu_16 (TFOpLambda)     (None, 56, 56, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 56, 56, 256)  589824      ['tf.nn.relu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  tf.nn.relu_17 (TFOpLambda)     (None, 56, 56, 256)  0           ['batch_normalization_17[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 25  0          ['tf.nn.relu_17[0][0]']
#                                 6)
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 2)  514         ['up_sampling2d_5[0][0]']
#
# ==================================================================================================
# Total params: 11,852,610
# Trainable params: 11,819,874
# Non-trainable params: 32,736
# __________________________________________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 179>()
#     223 model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)
#     225 callbacks = [
#     226     ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#     227     ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
#    (...)
#     230     EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
#     231 ]
# --> 233 history = model.fit(
#     234     train_dataset,
#     235     epochs=num_epoch,
#     236     validation_data=val_dataset,
#     237     steps_per_epoch=train_steps,
#     238     validation_steps=valid_steps,
#     239     callbacks=callbacks
#     240 )
#     244 plt.plot(history.history["loss"])
#     245 plt.title("Training Loss")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "C:\Users\Haris\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Haris\AppData\Local\Temp\ipykernel_9008\2664358455.py", line 99, in dice_coef  *
#         intersection = tf.reduce_sum(y_true * y_pred)
#
#     ValueError: Dimensions must be equal, but are 50176 and 100352 for '{{node mul_1}} = Mul[T=DT_FLOAT](flatten/Reshape, flatten_1/Reshape)' with input shapes: [?,50176], [?,100352].
