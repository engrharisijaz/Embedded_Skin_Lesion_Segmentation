# %%
# !pip install segmentation-models
# !pip install tensorflow==2.8
# !pip install keras==2.8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: segmentation-models in c:\users\haris\appdata\roaming\python\python39\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\programdata\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.21.5)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.7.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.7.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.0.1)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.7.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (22.12.6)
# Requirement already satisfied: gast>=0.2.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.29.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.42.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (3.6.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (4.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.21.5)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (1.12.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (61.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.1.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.3.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.8) (3.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\haris\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\haris\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras==2.8 in c:\users\haris\appdata\roaming\python\python39\site-packages (2.8.0)

# %%
import sys

sys.path.append('c:/users/haris/appdata/roaming/python/python39/site-packages')

# %%
# %matplotlib inline

# %%
import glob
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import tensorflow as tf
import segmentation_models as sm
BACKBONE = 'mobilenetv2'
preprocess_input = sm.get_preprocessing(BACKBONE)
# Out:
# Segmentation Models: using `keras` framework.

# %%
sm.set_framework('tf.keras')

sm.framework()
# Out:
# 'tf.keras'

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision


H = 224
W = 224

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(dataset_path, split=0.1):
    images = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset17/ISIC-2017_Training_Data", "*.jpg")))
    masks = sorted(glob(os.path.join(dataset_path, "C:/Users/Haris/ICAI_Paper/Dataset17/ISIC-2017_Training_Part1_GroundTruth", "*.png")))

    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x                                ## (256, 256, 3)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)                    ## (256, 256)
    x = np.expand_dims(x, axis=-1)              ## (256, 256, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving data """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 32
    lr = 1e-4 ## (0.0001)
    num_epoch = 200
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset : 80/10/10 """
    dataset_path = "C:/Users/Haris/ICAI_Paper/Dataset17"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch_size)

    train_steps = len(train_x)//batch_size
    valid_steps = len(valid_x)//batch_size

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1

    """ Model """
    model = sm.Unet(BACKBONE, encoder_weights='imagenet')
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)


    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=valid_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# Train: 1720 - 1720
# Valid: 215 - 215
# Test: 215 - 215
# C:\Users\Haris\AppData\Roaming\Python\Python39\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Epoch 1/200
# 54/54 [==============================] - ETA: 0s - loss: 0.3845 - dice_coef: 0.4562 - iou: 0.3014 - recall: 0.6594 - precision: 0.6512
# Epoch 1: val_loss improved from inf to 2.32995, saving model to files\model.h5
# 54/54 [==============================] - 226s 4s/step - loss: 0.3845 - dice_coef: 0.4562 - iou: 0.3014 - recall: 0.6594 - precision: 0.6512 - val_loss: 2.3300 - val_dice_coef: 0.3968 - val_iou: 0.2499 - val_recall: 0.9921 - val_precision: 0.2376 - lr: 1.0000e-04
# Epoch 2/200
# 54/54 [==============================] - ETA: 0s - loss: 0.1983 - dice_coef: 0.6629 - iou: 0.4979 - recall: 0.8932 - precision: 0.8926
# Epoch 2: val_loss improved from 2.32995 to 0.79287, saving model to files\model.h5
# 54/54 [==============================] - 196s 4s/step - loss: 0.1983 - dice_coef: 0.6629 - iou: 0.4979 - recall: 0.8932 - precision: 0.8926 - val_loss: 0.7929 - val_dice_coef: 0.5451 - val_iou: 0.3768 - val_recall: 0.8913 - val_precision: 0.5467 - lr: 1.0000e-04
# Epoch 3/200
# 54/54 [==============================] - ETA: 0s - loss: 0.1331 - dice_coef: 0.7577 - iou: 0.6114 - recall: 0.9140 - precision: 0.9298
# Epoch 3: val_loss improved from 0.79287 to 0.27997, saving model to files\model.h5
# 54/54 [==============================] - 196s 4s/step - loss: 0.1331 - dice_coef: 0.7577 - iou: 0.6114 - recall: 0.9140 - precision: 0.9298 - val_loss: 0.2800 - val_dice_coef: 0.5673 - val_iou: 0.3968 - val_recall: 0.5839 - val_precision: 0.9377 - lr: 1.0000e-04
# Epoch 4/200
# 54/54 [==============================] - ETA: 0s - loss: 0.1092 - dice_coef: 0.7987 - iou: 0.6662 - recall: 0.9173 - precision: 0.9384
# Epoch 4: val_loss did not improve from 0.27997
# 54/54 [==============================] - 195s 4s/step - loss: 0.1092 - dice_coef: 0.7987 - iou: 0.6662 - recall: 0.9173 - precision: 0.9384 - val_loss: 0.3063 - val_dice_coef: 0.5283 - val_iou: 0.3596 - val_recall: 0.4426 - val_precision: 0.9878 - lr: 1.0000e-04
# Epoch 5/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0955 - dice_coef: 0.8232 - iou: 0.7005 - recall: 0.9235 - precision: 0.9411
# Epoch 5: val_loss improved from 0.27997 to 0.22109, saving model to files\model.h5
# 54/54 [==============================] - 196s 4s/step - loss: 0.0955 - dice_coef: 0.8232 - iou: 0.7005 - recall: 0.9235 - precision: 0.9411 - val_loss: 0.2211 - val_dice_coef: 0.6750 - val_iou: 0.5100 - val_recall: 0.6497 - val_precision: 0.9396 - lr: 1.0000e-04
# Epoch 6/200
# 54/54 [==============================] - ETA: 0s - loss: 0.
200
# 54/54 [==============================] - ETA: 0s - loss: 0.0349 - dice_coef: 0.9260 - iou: 0.8626 - recall: 0.9766 - precision: 0.9806
# Epoch 85: val_loss improved from 0.13588 to 0.13576, saving model to files\model.h5
# 54/54 [==============================] - 209s 4s/step - loss: 0.0349 - dice_coef: 0.9260 - iou: 0.8626 - recall: 0.9766 - precision: 0.9806 - val_loss: 0.1358 - val_dice_coef: 0.8443 - val_iou: 0.7311 - val_recall: 0.8457 - val_precision: 0.9343 - lr: 1.0000e-07
# Epoch 86/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0349 - dice_coef: 0.9261 - iou: 0.8627 - recall: 0.9766 - precision: 0.9806
# Epoch 86: val_loss improved from 0.13576 to 0.13566, saving model to files\model.h5
# 54/54 [==============================] - 200s 4s/step - loss: 0.0349 - dice_coef: 0.9261 - iou: 0.8627 - recall: 0.9766 - precision: 0.9806 - val_loss: 0.1357 - val_dice_coef: 0.8445 - val_iou: 0.7314 - val_recall: 0.8460 - val_precision: 0.9342 - lr: 1.0000e-07
# Epoch 87/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0349 - dice_coef: 0.9261 - iou: 0.8628 - recall: 0.9766 - precision: 0.9806
# Epoch 87: val_loss improved from 0.13566 to 0.13556, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.0349 - dice_coef: 0.9261 - iou: 0.8628 - recall: 0.9766 - precision: 0.9806 - val_loss: 0.1356 - val_dice_coef: 0.8446 - val_iou: 0.7316 - val_recall: 0.8464 - val_precision: 0.9341 - lr: 1.0000e-07
# Epoch 88/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0349 - dice_coef: 0.9262 - iou: 0.8628 - recall: 0.9767 - precision: 0.9807
# Epoch 88: val_loss improved from 0.13556 to 0.13546, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.0349 - dice_coef: 0.9262 - iou: 0.8628 - recall: 0.9767 - precision: 0.9807 - val_loss: 0.1355 - val_dice_coef: 0.8448 - val_iou: 0.7318 - val_recall: 0.8467 - val_precision: 0.9340 - lr: 1.0000e-07
# Epoch 89/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0349 - dice_coef: 0.9262 - iou: 0.8629 - recall: 0.9767 - precision: 0.9807
# Epoch 89: val_loss improved from 0.13546 to 0.13537, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.0349 - dice_coef: 0.9262 - iou: 0.8629 - recall: 0.9767 - precision: 0.9807 - val_loss: 0.1354 - val_dice_coef: 0.8449 - val_iou: 0.7320 - val_recall: 0.8470 - val_precision: 0.9339 - lr: 1.0000e-07
# Epoch 90/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0348 - dice_coef: 0.9263 - iou: 0.8630 - recall: 0.9767 - precision: 0.9807
# Epoch 90: val_loss improved from 0.13537 to 0.13527, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.0348 - dice_coef: 0.9263 - iou: 0.8630 - recall: 0.9767 - precision: 0.9807 - val_loss: 0.1353 - val_dice_coef: 0.8450 - val_iou: 0.7322 - val_recall: 0.8473 - val_precision: 0.9338 - lr: 1.0000e-07
# Epoch 91/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0348 - dice_coef: 0.9263 - iou: 0.8631 - recall: 0.9767 - precision: 0.9807
# Epoch 91: val_loss improved from 0.13527 to 0.13518, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.0348 - dice_coef: 0.9263 - iou: 0.8631 - recall: 0.9767 - precision: 0.9807 - val_loss: 0.1352 - val_dice_coef: 0.8452 - val_iou: 0.7324 - val_recall: 0.8476 - val_precision: 0.9337 - lr: 1.0000e-07
# Epoch 92/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0348 - dice_coef: 0.9264 - iou: 0.8631 - recall: 0.9768 - precision: 0.9807
# Epoch 92: val_loss improved from 0.13518 to 0.13510, saving model to files\model.h5
# 54/54 [==============================] - 199s 4s/step - loss: 0.
200
# 54/54 [==============================] - ETA: 0s - loss: 0.0337 - dice_coef: 0.9284 - iou: 0.8667 - recall: 0.9779 - precision: 0.9815
# Epoch 138: val_loss did not improve from 0.13396
# 54/54 [==============================] - 198s 4s/step - loss: 0.0337 - dice_coef: 0.9284 - iou: 0.8667 - recall: 0.9779 - precision: 0.9815 - val_loss: 0.1342 - val_dice_coef: 0.8484 - val_iou: 0.7373 - val_recall: 0.8536 - val_precision: 0.9320 - lr: 1.0000e-07
# Epoch 139/200
# 54/54 [==============================] - ETA: 0s - loss: 0.0337 - dice_coef: 0.9284 - iou: 0.8668 - recall: 0.9779 - precision: 0.9815
# Epoch 139: val_loss did not improve from 0.13396
# 54/54 [==============================] - 199s 4s/step - loss: 0.0337 - dice_coef: 0.9284 - iou: 0.8668 - recall: 0.9779 - precision: 0.9815 - val_loss: 0.1342 - val_dice_coef: 0.8484 - val_iou: 0.7374 - val_recall: 0.8536 - val_precision: 0.9320 - lr: 1.0000e-07

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['Conv1_pad[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['out_relu[0][0]']
#  ampling2D)                     1280)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          1856)                            ',
#                                                                   'block_13_expand_relu[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   4276224     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          448)                             ',
#                                                                   'block_6_expand_relu[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   516096      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          272)                             ',
#                                                                   'block_3_expand_relu[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   156672      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          160)                             ',
#                                                                   'block_1_expand_relu[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   46080       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   145         ['decoder_stage4b_relu[0][0]']
#                                 1)
#
#  sigmoid (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 8,047,441
# Trainable params: 8,011,345
# Non-trainable params: 36,096
# __________________________________________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score



H = 224
W = 224

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    return ori_x, x                                ## (1, 256, 256, 3)


def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)                    ## (256, 256)
    return ori_x, x

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)  ## (256, 256, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1) ## (256, 256, 3)

    y_pred = np.expand_dims(y_pred, axis=-1)  ## (256, 256, 1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) ## (256, 256, 3)

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_images)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving results """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
        model = tf.keras.models.load_model("files/model.h5")

    """ Load the test data """
    dataset_path = "C:/Users/Haris/ICAI_Paper/Dataset17"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Exctracting the image name """
        name = x.split("/")[-1]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Predicting the mask """
        y_pred = model.predict(x)[0] > 0.5
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred.astype(np.int32)

        """ Saving the predicted mask """
        save_image_path = f"results/{name}"
        save_results(ori_x, ori_y, y_pred, save_image_path)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ mean metrics values """
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns = ["Image Name", "Acc", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 215/215 [00:50<00:00,  4.22it/s]
# Accuracy: 0.96130
# F1: 0.88492
# Jaccard: 0.80999
# Recall: 0.89121
# Precision: 0.90845
